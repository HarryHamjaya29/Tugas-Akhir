# %%
import pandas as pd
import os

import numpy as np
import math
import random
import itertools
import random
from sklearn.externals import joblib

import matplotlib.pyplot as plt
import math
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
label_file = "Dataset/new_bmi.csv"
data_df = pd.read_csv(label_file)
data_df
# Out:
#            1-2        1-3         1-4         1-5         1-6         1-7  \
# 0    16.124515  31.400637   47.518417   62.369865   77.491935   92.309263
# 1    16.124515  32.557641   49.030603   64.031242   78.434686   92.135769
# 2    11.045361  22.090722   33.241540   44.147480   54.083269   65.306967
# 3    15.000000  30.149627   44.283180   59.682493   73.756356   86.683332
# 4    21.000000  42.011903   61.294372   80.603970   96.767763  112.805142
# ..         ...        ...         ...         ...         ...         ...
# 967  12.369317  25.495098   37.336309   50.089919   61.073726   71.700767
# 968  24.083189  47.675990   69.634761   91.482239  112.946890  134.851770
# 969  30.066593  60.000000   90.049986  119.339851  146.512798  169.858765
# 970  24.020824  48.010416   76.791927  108.258949  140.687597  174.874241
# 971  34.058773  70.007142  104.043260  137.615406  169.852878  198.917068
#
#             1-8         1-9        1-10        1-11  ...      64-66  \
# ...

# %%
data = data_df.drop(['bmi'], axis=1)

# %%
data
# Out:
#            1-2        1-3         1-4         1-5         1-6         1-7  \
# 0    16.124515  31.400637   47.518417   62.369865   77.491935   92.309263
# 1    16.124515  32.557641   49.030603   64.031242   78.434686   92.135769
# 2    11.045361  22.090722   33.241540   44.147480   54.083269   65.306967
# 3    15.000000  30.149627   44.283180   59.682493   73.756356   86.683332
# 4    21.000000  42.011903   61.294372   80.603970   96.767763  112.805142
# ..         ...        ...         ...         ...         ...         ...
# 967  12.369317  25.495098   37.336309   50.089919   61.073726   71.700767
# 968  24.083189  47.675990   69.634761   91.482239  112.946890  134.851770
# 969  30.066593  60.000000   90.049986  119.339851  146.512798  169.858765
# 970  24.020824  48.010416   76.791927  108.258949  140.687597  174.874241
# 971  34.058773  70.007142  104.043260  137.615406  169.852878  198.917068
#
#             1-8         1-9        1-10        1-11  ...      64-65  \
# ...

# %%
data_arr = data.to_numpy()
data_arr
# Out:
# array([[ 16.1245155 ,  31.40063694,  47.51841748, ...,   5.09901951,
#          11.04536102,   6.        ],
#        [ 16.1245155 ,  32.55764119,  49.03060269, ...,   6.32455532,
#          13.15294644,   7.        ],
#        [ 11.04536102,  22.09072203,  33.24154028, ...,   4.        ,
#           9.        ,   5.        ],
#        ...,
#        [ 30.06659276,  60.        ,  90.04998612, ...,  11.18033989,
#          21.02379604,  10.04987562],
#        [ 24.0208243 ,  48.01041554,  76.79192666, ...,  12.04159458,
#          22.8035085 ,  11.18033989],
#        [ 34.05877273,  70.00714249, 104.04326023, ...,  14.03566885,
#          29.15475947,  15.5241747 ]])

# %%
label = data_df['bmi']
label
# Out:
# 0      55.950000
# 1      56.700000
# 2      54.150000
# 3      55.450000
# 4      57.250000
#          ...
# 967    22.806990
# 968    23.301714
# 969    23.528365
# 970    23.819676
# 971    23.673004
# Name: bmi, Length: 972, dtype: float64

# %%
temp_label = label.to_numpy()
len(temp_label)
# Out:
# 972

# %%
data_label = []
for i in temp_label:
    data_label.append(i.astype('int'))
data_label
# Out:
# [55,
#  56,
#  54,
#  55,
#  57,
#  62,
#  59,
#  60,
#  55,
#  58,
#  58,
#  60,
#  56,
#  62,
#  56,
#  61,
#  58,
#  57,
#  55,
#  57,
#  59,
#  63,
#  63,
#  54,
#  55,
#  58,
#  59,
#  58,
#  57,
#  57,
#  57,
#  62,
#  57,
#  56,
#  56,
#  58,
#  54,
#  56,
#  58,
#  57,
#  55,
#  61,
#  59,
#  62,
#  54,
#  54,
#  54,
#  54,
#  60,
#  55,
#  61,
#  54,
#  54,
#  55,
#  58,
#  60,
#  57,
#  66,
#  54,
#  68,
#  56,
#  55,
#  54,
#  62,
#  56,
#  55,
#  61,
#  62,
#  54,
#  59,
#  59,
#  58,
#  59,
#  63,
#  56,
#  54,
#  60,
#  54,
#  55,
#  54,
#  60,
#  56,
#  60,
#  61,
#  59,
#  54,
#  64,
#  58,
#  56,
#  54,
#  63,
#  59,
#  58,
#  62,
#  55,
#  68,
#  58,
#  65,
#  57,
#  58,
#  61,
#  57,
#  58,
#  58,
#  61,
#  58,
#  61,
#  54,
#  60,
#  61,
#  60,
#  56,
#  55,
#  59,
#  62,
#  62,
#  56,
#  56,
#  59,
#  61,
#  63,
#  59,
#  54,
#  55,
#  55,
#  57,
#  58,
#  62,
#  66,
#  54,
#  60,
#  56,
#  62,
#  54,
#  56,
#  57,
#  54,
#  56,
#  56,
#  55,
#  63,
#  60,
# ...

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
data_new = SelectKBest(chi2, k=7).fit_transform(data_arr, data_label)

# %%
data_new
# Out:
# array([[121.20231021, 124.48293056, 123.14625451, ..., 126.3170614 ,
#         123.43419299, 126.24579201],
#        [143.17122616, 136.89411967, 137.41178989, ..., 140.43147795,
#         139.38794783, 143.05593312],
#        [ 85.86617495,  88.02272434,  87.66413178, ...,  86.92525525,
#          87.45856162,  88.48163651],
#        ...,
#        [243.87701819, 225.8583627 , 223.78561169, ..., 226.49061791,
#         226.60317738, 231.39792566],
#        [276.53752006, 284.15488734, 291.60589843, ..., 295.70593501,
#         300.64763428, 306.72626233],
#        [253.3396929 , 257.8410363 , 262.26894593, ..., 251.54323684,
#         255.1901252 , 250.44959573]])

# %%
index = 3
count = 0
for i in data_new[index]:
    for idx in range(len(data_arr[index])):
        if i == data_arr[index][idx]:
            count = count+1
            print(idx)
print(count)
# Out:
# 465
# 517
# 574
# 575
# 576
# 631
# 632
# 7

# %%
selection_data = data_df.iloc[:, [575,465,632,576,517,574,631,405,464,524,2278]]
selection_data
# Out:
#           10-19        8-26       11-19       10-20        9-19       10-18  \
# 0    127.141653  121.202310  126.245792  126.317061  124.482931  123.146255
# 1    142.358702  143.171226  143.055933  140.431478  136.894120  137.411790
# 2     89.470666   85.866175   88.481637   86.925255   88.022724   87.664132
# 3    115.693561  115.412304  110.941426  113.225439  112.641023  111.364267
# 4    151.158857  144.474911  149.412182  149.325149  148.081059  150.296374
# ..          ...         ...         ...         ...         ...         ...
# 967   88.294960   88.526832   85.440037   85.708809   85.586214   86.330759
# 968  184.707877  180.013888  180.853532  178.011236  179.513231  185.827877
# 969  230.902577  243.877018  231.397926  226.490618  225.858363  223.785612
# 970  298.187860  276.537520  306.726262  295.705935  284.154887  291.605898
# 971  259.988461  253.339693  250.449596  251.543237  257.841036  262.268946
#
# ...

# %%
selection_data.to_csv("selection_bmi_10.csv", encoding="utf-8", index=False)
