# %%
import pandas as pd
import os

import numpy as np
import math
import random
import itertools
import random
from sklearn.externals import joblib

import matplotlib.pyplot as plt
import math
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
label_file = "Dataset/new_height.csv"
data_df = pd.read_csv(label_file)
data_df
# Out:
#            1-2        1-3         1-4         1-5         1-6         1-7  \
# 0    16.124515  31.400637   47.518417   62.369865   77.491935   92.309263
# 1    16.124515  32.557641   49.030603   64.031242   78.434686   92.135769
# 2    11.045361  22.090722   33.241540   44.147480   54.083269   65.306967
# 3    15.000000  30.149627   44.283180   59.682493   73.756356   86.683332
# 4    21.000000  42.011903   61.294372   80.603970   96.767763  112.805142
# ..         ...        ...         ...         ...         ...         ...
# 481  12.369317  25.495098   37.336309   50.089919   61.073726   71.700767
# 482  24.083189  47.675990   69.634761   91.482239  112.946890  134.851770
# 483  30.066593  60.000000   90.049986  119.339851  146.512798  169.858765
# 484  24.020824  48.010416   76.791927  108.258949  140.687597  174.874241
# 485  34.058773  70.007142  104.043260  137.615406  169.852878  198.917068
#
#             1-8         1-9        1-10        1-11  ...      64-66  \
# ...

# %%
data = data_df.drop(['height'], axis=1)

# %%
data
# Out:
#            1-2        1-3         1-4         1-5         1-6         1-7  \
# 0    16.124515  31.400637   47.518417   62.369865   77.491935   92.309263
# 1    16.124515  32.557641   49.030603   64.031242   78.434686   92.135769
# 2    11.045361  22.090722   33.241540   44.147480   54.083269   65.306967
# 3    15.000000  30.149627   44.283180   59.682493   73.756356   86.683332
# 4    21.000000  42.011903   61.294372   80.603970   96.767763  112.805142
# ..         ...        ...         ...         ...         ...         ...
# 481  12.369317  25.495098   37.336309   50.089919   61.073726   71.700767
# 482  24.083189  47.675990   69.634761   91.482239  112.946890  134.851770
# 483  30.066593  60.000000   90.049986  119.339851  146.512798  169.858765
# 484  24.020824  48.010416   76.791927  108.258949  140.687597  174.874241
# 485  34.058773  70.007142  104.043260  137.615406  169.852878  198.917068
#
#             1-8         1-9        1-10        1-11  ...      64-65  \
# ...

# %%
data_arr = data.to_numpy()
data_arr
# Out:
# array([[ 16.1245155 ,  31.40063694,  47.51841748, ...,   5.09901951,
#          11.04536102,   6.        ],
#        [ 16.1245155 ,  32.55764119,  49.03060269, ...,   6.32455532,
#          13.15294644,   7.        ],
#        [ 11.04536102,  22.09072203,  33.24154028, ...,   4.        ,
#           9.        ,   5.        ],
#        ...,
#        [ 30.06659276,  60.        ,  90.04998612, ...,  11.18033989,
#          21.02379604,  10.04987562],
#        [ 24.0208243 ,  48.01041554,  76.79192666, ...,  12.04159458,
#          22.8035085 ,  11.18033989],
#        [ 34.05877273,  70.00714249, 104.04326023, ...,  14.03566885,
#          29.15475947,  15.5241747 ]])

# %%
label = data_df['height']
label
# Out:
# 0      155.95
# 1      156.70
# 2      154.15
# 3      155.45
# 4      157.25
#         ...
# 481    154.30
# 482    158.65
# 483    160.95
# 484    164.30
# 485    162.55
# Name: height, Length: 486, dtype: float64

# %%
temp_label = label.to_numpy()
len(temp_label)
# Out:
# 486

# %%
data_label = []
for i in temp_label:
    data_label.append(i.astype('int'))
data_label
# Out:
# [155,
#  156,
#  154,
#  155,
#  157,
#  162,
#  159,
#  160,
#  155,
#  158,
#  158,
#  160,
#  156,
#  162,
#  156,
#  161,
#  158,
#  157,
#  155,
#  157,
#  159,
#  163,
#  163,
#  154,
#  155,
#  158,
#  159,
#  158,
#  157,
#  157,
#  157,
#  162,
#  157,
#  156,
#  156,
#  158,
#  154,
#  156,
#  158,
#  157,
#  155,
#  161,
#  159,
#  162,
#  154,
#  154,
#  154,
#  154,
#  160,
#  155,
#  161,
#  154,
#  154,
#  155,
#  158,
#  160,
#  157,
#  166,
#  154,
#  168,
#  156,
#  155,
#  154,
#  162,
#  156,
#  155,
#  161,
#  162,
#  154,
#  159,
#  159,
#  158,
#  159,
#  163,
#  156,
#  154,
#  160,
#  154,
#  155,
#  154,
#  160,
#  156,
#  160,
#  161,
#  159,
#  154,
#  164,
#  158,
#  156,
#  154,
#  163,
#  159,
#  158,
#  162,
#  155,
#  168,
#  158,
#  165,
#  157,
#  158,
#  161,
#  157,
#  158,
#  158,
#  161,
#  158,
#  161,
#  154,
#  160,
#  161,
#  160,
#  156,
#  155,
#  159,
#  162,
#  162,
#  156,
#  156,
#  159,
#  161,
#  163,
#  159,
#  154,
#  155,
#  155,
# ...

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
data_height_new = SelectKBest(chi2, k=5).fit_transform(data_arr, data_label)

# %%
data_height_new
# Out:
# array([[121.20231021, 124.48293056, 127.14165328, 126.3170614 ,
#         126.24579201],
#        [143.17122616, 136.89411967, 142.35870188, 140.43147795,
#         143.05593312],
#        [ 85.86617495,  88.02272434,  89.47066558,  86.92525525,
#          88.48163651],
#        ...,
#        [243.87701819, 225.8583627 , 230.90257686, 226.49061791,
#         231.39792566],
#        [276.53752006, 284.15488734, 298.18786025, 295.70593501,
#         306.72626233],
#        [253.3396929 , 257.8410363 , 259.98846128, 251.54323684,
#         250.44959573]])

# %%
index = 280
count = 0
for i in data_height_new[index]:
    for idx in range(len(data_arr[index])):
        if i == data_arr[index][idx]:
            count = count+1
            print(idx)
print(count)
# Out:
# 465
# 517
# 575
# 576
# 632
# 5

# %%
selection_data = data_df.iloc[:, [575,2278]]
selection_data
# Out:
#           10-19  height
# 0    127.141653  155.95
# 1    142.358702  156.70
# 2     89.470666  154.15
# 3    115.693561  155.45
# 4    151.158857  157.25
# ..          ...     ...
# 481   88.294960  154.30
# 482  184.707877  158.65
# 483  230.902577  160.95
# 484  298.187860  164.30
# 485  259.988461  162.55
#
# [486 rows x 2 columns]

# %%
selection_data.to_csv("selection_height_1.csv", encoding="utf-8", index=False)
