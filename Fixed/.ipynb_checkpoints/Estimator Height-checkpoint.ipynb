# %%
import pandas as pd
import os

import numpy as np
import math
import itertools
import random
from sklearn.externals import joblib

import matplotlib.pyplot as plt
import math
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
label_file = "./samplereal.csv"

# %%
data_df = pd.read_csv(label_file)
data_df.drop(['Unnamed: 0'], axis=1)
# Out:
#             bmi  gender          name  width  length  height      weight
# 0     34.207396    Male     img_0.bmp     97      85     154   81.126261
# 1     26.453720    Male     img_1.bmp     85      83     154   62.737642
# 2     34.967561  Female     img_2.bmp    129     124     156   85.097055
# 3     22.044766  Female     img_3.bmp     68      72     154   52.281368
# 4     37.758789  Female     img_4.bmp    830     837     179  120.982936
# ...         ...     ...           ...    ...     ...     ...         ...
# 4032  66.556213    Male  img_4032.bmp    372     367     164  179.009591
# 4033  42.429586    Male  img_4033.bmp    290     302     162  111.352205
# 4034  33.903359    Male  img_4034.bmp    213     209     158   84.636345
# 4035  29.286170    Male  img_4035.bmp    167     170     157   72.187480
# 4036  35.689492    Male  img_4036.bmp    233     228     159   90.226606
#
# [4037 rows x 7 columns]

# %%
y_height = data_df.height.values ## all labels
y_distance = data_df.length.values

# %%
X_train = []

# %%
for i in  y_distance:
    X_train.append([0,i])

# %%
X_train
# Out:
# [[0, 85],
#  [0, 83],
#  [0, 124],
#  [0, 72],
#  [0, 837],
#  [0, 889],
#  [0, 59],
#  [0, 52],
#  [0, 182],
#  [0, 185],
#  [0, 68],
#  [0, 66],
#  [0, 406],
#  [0, 374],
#  [0, 101],
#  [0, 312],
#  [0, 175],
#  [0, 119],
#  [0, 146],
#  [0, 134],
#  [0, 87],
#  [0, 83],
#  [0, 76],
#  [0, 109],
#  [0, 144],
#  [0, 145],
#  [0, 299],
#  [0, 440],
#  [0, 94],
#  [0, 245],
#  [0, 360],
#  [0, 330],
#  [0, 73],
#  [0, 73],
#  [0, 171],
#  [0, 196],
#  [0, 70],
#  [0, 291],
#  [0, 69],
#  [0, 83],
#  [0, 649],
#  [0, 573],
#  [0, 271],
#  [0, 176],
#  [0, 50],
#  [0, 55],
#  [0, 153],
#  [0, 246],
#  [0, 162],
#  [0, 135],
#  [0, 34],
#  [0, 33],
#  [0, 99],
#  [0, 91],
#  [0, 49],
#  [0, 56],
#  [0, 189],
#  [0, 208],
#  [0, 109],
#  [0, 321],
#  [0, 124],
#  [0, 108],
#  [0, 71],
#  [0, 49],
#  [0, 253],
#  [0, 119],
#  [0, 156],
#  [0, 138],
#  [0, 262],
#  [0, 215],
#  [0, 218],
#  [0, 261],
#  [0, 391],
#  [0, 391],
#  [0, 183],
#  [0, 173],
#  [0, 68],
#  [0, 182],
#  [0, 339],
#  [0, 193],
#  [0, 47],
#  [0, 52],
#  [0, 128],
#  [0, 109],
#  [0, 53],
#  [0, 52],
#  [0, 545],
#  [0, 489],
#  [0, 71],
#  [0, 75],
#  [0, 112],
#  [0, 115],
#  [0, 478],
#  [0, 771],
#  [0, 286],
#  [0, 291],
#  [0, 187],
#  [0, 226],
#  [0, 158],
#  [0, 143],
#  [0, 155],
#  [0, 178],
#  [0, 100],
#  [0, 99],
#  [0, 87],
#  [0, 58],
#  [0, 63],
#  [0, 51],
#  [0, 58],
#  [0, 149],
#  [0, 263],
#  [0, 427],
#  [0, 400],
#  [0, 146],
#  [0, 228],
#  [0, 179],
#  [0, 180],
#  [0, 263],
#  [0, 243],
#  [0, 81],
#  [0, 80],
#  [0, 534],
#  [0, 532],
#  [0, 97],
#  [0, 71],
#  [0, 102],
#  [0, 132],
#  [0, 96],
#  [0, 104],
#  [0, 270],
#  [0, 250],
#  [0, 67],
#  [0, 61],
#  [0, 120],
#  [0, 139],
#  [0, 324],
#  [0, 324],
#  [0, 120],
#  [0, 105],
#  [0, 78],
#  [0, 90],
#  [0, 80],
#  [0, 65],
#  [0, 83],
#  [0, 134],
#  [0, 219],
#  [0, 246],
#  ...]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_height_train, y_height_test = train_test_split(X_train, y_height, test_size=0.05, random_state=1)

# %%
from sklearn.kernel_ridge import KernelRidge
from sklearn import  linear_model
from sklearn.svm import SVR
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from math import sqrt

# %%
def report_goodness(model,X_test,y_test,predictor_log=True):
    # Make predictions using the testing set
    y_pred = model.predict(X_test)
    y_true = y_test
    if predictor_log:
        y_true = np.log(y_test)
    print('Model Performance')
    print("Root Mean squared error: %.4f" %sqrt(mean_squared_error(y_true, y_pred)))
    print("Mean squared error: %.4f" %mean_squared_error(y_true, y_pred))
    print('Mean Absolute Error: %.4f' %mean_absolute_error(y_true, y_pred))
    print('Variant score: %.4f' %r2_score(y_true, y_pred))

# %%
model_linear = linear_model.LinearRegression()
model_linear = model_linear.fit(X_train,np.log(y_height_train))

report_goodness(model_linear,X_test,y_height_test)
# Out:
# Model Performance
# Root Mean squared error: 0.0023
# Mean squared error: 0.0000
# Mean Absolute Error: 0.0018
# Variant score: 0.9965

# %%
model_ridge = Ridge(fit_intercept=True, alpha=0.0015, random_state=4, normalize=True)
model_ridge = model_ridge.fit(X_train,np.log(y_height_train))

report_goodness(model_ridge,X_test,y_height_test)
# Out:
# Model Performance
# Root Mean squared error: 0.0023
# Mean squared error: 0.0000
# Mean Absolute Error: 0.0018
# Variant score: 0.9966

# %%
model_lasso = Lasso(fit_intercept=True, alpha=0.0015, random_state=4, normalize=True)
model_lasso = model_lasso.fit(X_train,np.log(y_height_train))

report_goodness(model_lasso,X_test,y_height_test)
# Out:
# Model Performance
# Root Mean squared error: 0.0387
# Mean squared error: 0.0015
# Mean Absolute Error: 0.0277
# Variant score: -0.0019

# %%
height_model = 'height_predictor_height_best.model'
joblib.dump(model_ridge, height_model)
# Out:
# ['height_predictor_height_best.model']

# %%
label_file = "./MainSample_test.csv"

# %%
data_df_test = pd.read_csv(label_file)
data_df_test.drop(['Unnamed: 0'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-c9d45824fd84> in <module>
# ----> 1 data_df_test = pd.read_csv(label_file)
#       2 data_df_test.drop(['Unnamed: 0'], axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./MainSample_test.csv' does not exist: b'./MainSample_test.csv'

# %%
y_distance = data_df_test.distance.values ## all labels

# %%
df_height = pd.DataFrame(columns=['Ground Truth', 'Estimation'])

# %%
df_height['Ground Truth'] = data_df_test['height']
df_height['Ground Truth']

# %%
temp = []
res = []
temp_test = []
data_test = []

# %%
def test(model,X_test,predictor_log=True):
    # Make predictions using the testing set
    y_pred = model.predict(X_test)
    return y_pred

# %%
for i in  y_distance:
    data_test.append([0,i])

# %%
temp = test(model_ridge,data_test)
temp

# %%
for i in temp:
    res.append(math.exp(i))

# %%
res

# %%
len(res)

# %%
df_height['Estimation'] = res
df_height['Estimation']

# %%
df_height.to_csv('height_final.csv', index=False)
