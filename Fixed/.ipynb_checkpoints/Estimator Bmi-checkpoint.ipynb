# %%
import pandas as pd
import os

import numpy as np
import math
import itertools
import random
from sklearn.externals import joblib

import matplotlib.pyplot as plt
import math
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
label_file = "./bmi.csv"

# %%
data_df = pd.read_csv(label_file)
data_df.drop(['Unnamed: 0'], axis=1)
# Out:
#             bmi  gender          name  length  height  weight
# 0     34.207396    Male     img_0.bmp      85     157   84.32
# 1     26.453720    Male     img_1.bmp      83     156   64.38
# 2     34.967561  Female     img_2.bmp      99     158   87.29
# 3     22.044766  Female     img_3.bmp      72     157   54.34
# 4     37.758789  Female     img_4.bmp     106     157   93.07
# ...         ...     ...           ...     ...     ...     ...
# 4038  40.422500  Female  img_4038.bmp     121     164  108.72
# 4039  29.682222  Female  img_4039.bmp     120     163   78.86
# 4040  61.649679  Female  img_4040.bmp      94     158  153.90
# 4041  53.741736  Female  img_4041.bmp      94     156  130.79
# 4042  44.020156  Female  img_4042.bmp      84     157  108.51
#
# [4043 rows x 6 columns]

# %%
y_height = data_df.height.values ## all labels
y_weight = data_df.weight.values
y_bmi = data_df.bmi.values

# %%
X_train = []

# %%
for i in  range(len(y_height)):
    X_train.append([y_height[i],y_weight[i]])

# %%
X_train
# Out:
# [[157, 84.32],
#  [156, 64.38],
#  [158, 87.29],
#  [157, 54.34],
#  [157, 93.07],
#  [180, 80.63],
#  [156, 62.9],
#  [156, 52.91],
#  [180, 99.2],
#  [176, 82.98],
#  [156, 94.26],
#  [159, 77.93],
#  [158, 103.35],
#  [171, 90.79],
#  [158, 88.78],
#  [157, 85.33],
#  [173, 127.41],
#  [159, 59.65],
#  [161, 106.82],
#  [157, 52.53],
#  [159, 67.3],
#  [156, 52.64],
#  [156, 101.75],
#  [156, 54.39],
#  [159, 85.48],
#  [157, 61.34],
#  [183, 135.61],
#  [158, 77.02],
#  [156, 76.54],
#  [156, 49.59],
#  [163, 90.08],
#  [156, 67.65],
#  [157, 77.57],
#  [156, 56.95],
#  [166, 80.53],
#  [181, 72.53],
#  [158, 77.8],
#  [185, 93.89],
#  [156, 101.45],
#  [157, 89.42],
#  [157, 97.55],
#  [174, 87.47],
#  [169, 124.34],
#  [170, 102.94],
#  [159, 92.25],
#  [159, 65.34],
#  [163, 100.78],
#  [157, 74.94],
#  [166, 121.45],
#  [157, 100.28],
#  [157, 68.58],
#  [158, 53.13],
#  [159, 92.25],
#  [159, 69.18],
#  [158, 89.19],
#  [157, 52.46],
#  [180, 122.88],
#  [159, 59.16],
#  [159, 96.76],
#  [158, 86.29],
#  [156, 73.6],
#  [156, 53.53],
#  [158, 83.13],
#  [156, 58.19],
#  [163, 99.86],
#  [157, 65.62],
#  [163, 136.8],
#  [159, 65.08],
#  [168, 117.66],
#  [159, 74.71],
#  [157, 93.6],
#  [169, 91.08],
#  [178, 132.98],
#  [183, 88.11],
#  [174, 155.89],
#  [177, 75.28],
#  [157, 78.75],
#  [179, 109.19],
#  [158, 99.69],
#  [182, 157.23],
#  [158, 98.52],
#  [159, 68.1],
#  [159, 116.92],
#  [159, 73.85],
#  [158, 103.6],
#  [158, 77.02],
#  [160, 138.56],
#  [178, 120.43],
#  [159, 135.74],
#  [158, 85.29],
#  [159, 125.75],
#  [158, 100.77],
#  [173, 105.18],
#  [174, 83.15],
#  [180, 120.67],
#  [185, 111.61],
#  [180, 136.93],
#  [157, 73.82],
#  [166, 80.7],
#  [158, 62.67],
#  [165, 81.22],
#  [171, 71.38],
#  [157, 91.8],
#  [159, 81.14],
#  [159, 106.79],
#  [156, 74.84],
#  [160, 76.38],
#  [157, 60.17],
#  [178, 111.37],
#  [171, 75.09],
#  [156, 62.17],
#  [157, 70.08],
#  [169, 111.93],
#  [166, 96.78],
#  [188, 120.45],
#  [156, 62.2],
#  [159, 98.99],
#  [158, 70.51],
#  [156, 82.28],
#  [158, 129.04],
#  [178, 113.43],
#  [157, 58.83],
#  [159, 96.09],
#  [159, 82.25],
#  [156, 92.5],
#  [159, 75.33],
#  [167, 102.09],
#  [163, 78.69],
#  [158, 107.92],
#  [157, 79.06],
#  [158, 95.64],
#  [159, 68.03],
#  [157, 91.1],
#  [159, 77.6],
#  [157, 115.99],
#  [159, 94.28],
#  [159, 106.39],
#  [156, 91.99],
#  [167, 150.68],
#  [157, 114.65],
#  [156, 85.1],
#  [158, 81.22],
#  [168, 122.29],
#  [159, 61.5],
#  [158, 78.97],
#  [156, 65.55],
#  [159, 95.05],
#  [157, 58.53],
#  [157, 116.99],
#  [166, 87.82],
#  [157, 72.87],
#  [157, 66.85],
#  [158, 95.47],
#  [156, 65.76],
#  [184, 201.41],
#  [164, 92.77],
#  [185, 129.23],
#  [160, 65.91],
#  [158, 71.51],
#  [161, 65.45],
#  [163, 68.61],
#  [161, 50.2],
#  [156, 83.73],
#  [162, 73.63],
#  [159, 74.65],
#  [158, 64.1],
#  [158, 91.09],
#  [158, 64.52],
#  [177, 113.18],
#  [158, 75.56],
#  [166, 73.24],
#  [157, 61.87],
#  [157, 62.85],
#  [157, 56.49],
#  [159, 83.73],
#  [158, 71.76],
#  [159, 71.09],
#  [156, 52.62],
#  [157, 94.27],
#  [159, 70.55],
#  [158, 85.89],
#  [184, 87.98],
#  [159, 79.44],
#  [171, 71.08],
#  [157, 72.79],
#  [185, 90.96],
#  [166, 69.17],
#  [161, 63.26],
#  [159, 67.31],
#  [156, 59.07],
#  [159, 80.63],
#  [159, 62.34],
#  [156, 74.66],
#  [158, 62.67],
#  [158, 74.48],
#  [163, 62.33],
#  [174, 83.77],
#  [181, 80.69],
#  [169, 69.58],
#  [167, 65.89],
#  [183, 103.94],
#  [177, 81.98],
#  [159, 59.85],
#  [156, 55.86],
#  [169, 69.48],
#  [179, 74.04],
#  [168, 67.8],
#  [163, 60.19],
#  [171, 109.67],
#  [157, 76.43],
#  [157, 58.53],
#  [159, 56.7],
#  [156, 73.32],
#  [188, 91.27],
#  [156, 68.45],
#  [158, 66.04],
#  [176, 80.88],
#  [169, 61.46],
#  [169, 76.42],
#  [159, 89.25],
#  [159, 90.68],
#  [163, 83.1],
#  [158, 70.5],
#  [158, 58.42],
#  [159, 83.38],
#  [157, 60.16],
#  [156, 84.35],
#  [158, 69.16],
#  [157, 86.91],
#  [158, 67.71],
#  [157, 68.75],
#  [157, 60.16],
#  [156, 88.24],
#  [158, 60.92],
#  [158, 117.83],
#  [158, 64.47],
#  [162, 87.91],
#  [166, 67.26],
#  [157, 81.06],
#  [175, 83.93],
#  [157, 89.17],
#  [157, 70.97],
#  [157, 102.6],
#  [167, 99.78],
#  [157, 109.31],
#  [157, 81.47],
#  [159, 83.14],
#  [159, 73.24],
#  [156, 75.9],
#  [159, 63.42],
#  [157, 98.02],
#  [187, 95.42],
#  [159, 109.71],
#  [158, 87.34],
#  [159, 113.14],
#  [164, 103.95],
#  [158, 105.01],
#  [156, 86.79],
#  [156, 77.7],
#  [184, 86.47],
#  [158, 92.66],
#  [156, 80.29],
#  [157, 88.07],
#  [159, 70.72],
#  [159, 89.14],
#  [159, 61.71],
#  [156, 64.03],
#  [158, 48.87],
#  [159, 89.59],
#  [156, 59.36],
#  [159, 89.56],
#  [159, 90.05],
#  [161, 97.46],
#  [158, 66.19],
#  [157, 114.3],
#  [157, 74.57],
#  [158, 85.8],
#  [156, 75.43],
#  [157, 83.24],
#  [156, 74.16],
#  [169, 139.41],
#  [156, 89.89],
#  [158, 111.4],
#  [157, 81.23],
#  [156, 69.48],
#  [177, 81.83],
#  [156, 62.88],
#  [158, 44.23],
#  [173, 74.7],
#  [156, 58.69],
#  [158, 88.92],
#  [159, 74.25],
#  [158, 79.38],
#  [159, 65.95],
#  [157, 78.89],
#  [159, 60.0],
#  [158, 101.79],
#  [182, 122.56],
#  [158, 99.99],
#  [159, 64.26],
#  [176, 114.2],
#  [157, 76.71],
#  [168, 104.63],
#  [173, 109.65],
#  [159, 130.73],
#  [158, 88.59],
#  [156, 82.5],
#  [157, 70.2],
#  [180, 123.1],
#  [176, 97.66],
#  [156, 125.3],
#  [156, 93.98],
#  [184, 92.48],
#  [158, 61.19],
#  [159, 97.63],
#  [159, 75.93],
#  [159, 112.94],
#  [156, 64.98],
#  [159, 86.1],
#  [176, 84.01],
#  [162, 86.01],
#  [169, 79.66],
#  [159, 103.21],
#  [157, 91.13],
#  [159, 72.67],
#  [156, 56.69],
#  [157, 107.82],
#  [159, 85.31],
#  [156, 89.73],
#  [160, 68.31],
#  [157, 108.19],
#  [158, 101.97],
#  [162, 79.8],
#  [178, 84.3],
#  [163, 98.14],
#  [177, 74.81],
#  [168, 118.77],
#  [158, 67.18],
#  [159, 67.32],
#  [158, 50.36],
#  [156, 80.26],
#  [158, 64.22],
#  [156, 72.14],
#  [167, 66.14],
#  [175, 97.22],
#  [156, 61.09],
#  [156, 79.36],
#  [158, 59.98],
#  [157, 104.05],
#  [158, 69.16],
#  [159, 110.86],
#  [157, 69.48],
#  [158, 75.21],
#  [156, 57.61],
#  [157, 92.64],
#  [157, 67.55],
#  [156, 103.41],
#  [159, 82.15],
#  [178, 149.55],
#  [179, 129.17],
#  [160, 84.75],
#  [170, 73.51],
#  [157, 121.2],
#  [179, 114.02],
#  [181, 139.45],
#  [162, 91.89],
#  [158, 92.86],
#  [158, 65.0],
#  [157, 90.57],
#  [182, 89.83],
#  [184, 156.13],
#  [166, 114.34],
#  [158, 94.0],
#  [169, 101.57],
#  [157, 101.49],
#  [156, 81.0],
#  [158, 100.27],
#  [159, 94.46],
#  [156, 93.46],
#  [158, 67.57],
#  [158, 112.81],
#  [157, 93.98],
#  [176, 163.42],
#  [187, 138.23],
#  [161, 74.38],
#  [159, 57.76],
#  [159, 99.42],
#  [158, 82.94],
#  [157, 72.96],
#  [159, 65.72],
#  [183, 153.5],
#  [159, 85.37],
#  [173, 91.77],
#  [156, 64.8],
#  [159, 95.88],
#  [168, 86.54],
#  [167, 96.09],
#  [176, 82.47],
#  [159, 100.05],
#  [157, 82.92],
#  [172, 129.72],
#  [165, 108.72],
#  [179, 121.82],
#  [177, 80.91],
#  [158, 74.98],
#  [156, 60.56],
#  [169, 82.24],
#  [156, 55.7],
#  [157, 110.18],
#  [159, 65.34],
#  [173, 120.21],
#  [157, 89.7],
#  [157, 60.86],
#  [157, 123.11],
#  [159, 141.34],
#  [157, 79.91],
#  [158, 110.67],
#  [159, 92.13],
#  [172, 139.45],
#  [167, 113.99],
#  [157, 70.47],
#  [159, 61.7],
#  [156, 92.31],
#  [159, 50.33],
#  [156, 92.71],
#  [158, 69.88],
#  [172, 85.65],
#  [157, 63.57],
#  [158, 84.78],
#  [159, 67.19],
#  [158, 73.05],
#  [157, 55.0],
#  [159, 113.02],
#  [158, 93.87],
#  [184, 208.9],
#  [157, 87.91],
#  [164, 91.74],
#  [166, 83.0],
#  [156, 75.44],
#  [159, 70.37],
#  [156, 133.54],
#  [159, 81.6],
#  [159, 90.98],
#  [157, 51.71],
#  [159, 126.84],
#  [157, 63.71],
#  [189, 94.65],
#  [158, 63.81],
#  [158, 84.17],
#  [157, 76.03],
#  [158, 80.46],
#  [158, 61.86],
#  [159, 92.25],
#  [158, 75.91],
#  [158, 76.55],
#  [158, 60.43],
#  [160, 74.37],
#  [157, 69.62],
#  [156, 78.55],
#  [177, 78.87],
#  [156, 93.67],
#  [158, 88.08],
#  [178, 86.83],
#  [167, 70.75],
#  [173, 80.67],
#  [167, 65.89],
#  [159, 91.67],
#  [158, 55.7],
#  [158, 93.1],
#  [157, 61.84],
#  [156, 98.35],
#  [157, 65.52],
#  [157, 104.74],
#  [157, 73.93],
#  [159, 96.84],
#  [156, 83.1],
#  [159, 64.45],
#  [156, 56.27],
#  [171, 107.14],
#  [157, 67.19],
#  [159, 90.96],
#  [158, 66.84],
#  [158, 129.04],
#  [158, 83.5],
#  [174, 98.38],
#  [163, 57.06],
#  [159, 95.53],
#  [159, 62.09],
#  [158, 74.08],
#  [159, 57.59],
#  [159, 92.89],
#  [156, 63.87],
#  [159, 86.98],
#  [156, 70.43],
#  [159, 98.46],
#  [159, 70.77],
#  [164, 90.68],
#  [169, 85.64],
#  [157, 125.68],
#  [158, 93.1],
#  [158, 70.04],
#  [176, 73.18],
#  [159, 96.25],
#  [167, 73.9],
#  [182, 149.57],
#  [159, 78.79],
#  [157, 108.64],
#  [159, 70.28],
#  [156, 94.52],
#  [157, 60.22],
#  [170, 85.35],
#  [167, 72.07],
#  [171, 93.98],
#  [156, 57.75],
#  [156, 59.29],
#  [159, 57.86],
#  [163, 63.05],
#  [159, 54.68],
#  [179, 120.43],
#  [166, 69.05],
#  [159, 87.1],
#  [158, 60.99],
#  [156, 96.94],
#  [159, 79.95],
#  [164, 96.47],
#  [156, 59.36],
#  [159, 83.38],
#  [157, 65.03],
#  [157, 100.28],
#  [163, 59.09],
#  [175, 112.11],
#  [178, 99.64],
#  [159, 97.31],
#  [159, 86.38],
#  [173, 110.06],
#  [167, 83.99],
#  [159, 113.02],
#  [159, 92.21],
#  [157, 105.87],
#  [156, 96.38],
#  [159, 99.74],
#  [168, 72.89],
#  [158, 75.31],
#  [157, 60.12],
#  [157, 141.46],
#  [159, 134.2],
#  [180, 124.31],
#  [186, 94.81],
#  [175, 95.8],
#  [188, 78.22],
#  [157, 98.1],
#  [157, 88.6],
#  [159, 94.13],
#  [158, 73.11],
#  [156, 125.53],
#  [156, 76.94],
#  [156, 91.24],
#  [158, 71.76],
#  [177, 77.13],
#  [167, 61.75],
#  [178, 127.83],
#  [179, 108.59],
#  [162, 91.05],
#  [169, 77.24],
#  [158, 82.04],
#  [157, 74.7],
#  [156, 85.1],
#  [158, 62.62],
#  [158, 61.6],
#  [156, 50.63],
#  [158, 81.8],
#  [179, 90.8],
#  [156, 68.6],
#  [157, 67.94],
#  [159, 76.52],
#  [187, 73.07],
#  [189, 106.29],
#  [169, 64.86],
#  [166, 80.7],
#  [171, 68.69],
#  [157, 103.06],
#  [159, 80.33],
#  [179, 133.15],
#  [156, 83.47],
#  [159, 64.93],
#  [160, 97.9],
#  [157, 73.34],
#  [159, 63.35],
#  [158, 75.34],
#  [158, 64.86],
#  [159, 89.42],
#  [157, 59.46],
#  [175, 112.84],
#  [167, 93.81],
#  [157, 104.05],
#  [157, 64.38],
#  [159, 97.31],
#  [158, 80.42],
#  [159, 80.77],
#  [159, 114.42],
#  [157, 86.73],
#  [156, 63.91],
#  [158, 75.21],
#  [159, 67.1],
#  [157, 78.26],
#  [159, 64.65],
#  [184, 136.6],
#  [179, 98.25],
#  [156, 73.84],
#  [158, 62.57],
#  [156, 63.73],
#  [156, 52.8],
#  [158, 100.44],
#  [156, 80.11],
#  [156, 80.99],
#  [158, 64.8],
#  [157, 120.44],
#  [157, 87.24],
#  [158, 80.07],
#  [157, 68.75],
#  [156, 165.98],
#  [159, 92.66],
#  [180, 102.26],
#  [158, 55.51],
#  [157, 73.08],
#  [159, 62.65],
#  [157, 121.71],
#  [158, 55.7],
#  [165, 108.44],
#  [189, 106.99],
#  [159, 90.44],
#  [156, 76.94],
#  [158, 74.28],
#  [156, 58.19],
#  [164, 106.39],
#  [156, 71.09],
#  [164, 86.27],
#  [157, 68.75],
#  [156, 101.54],
#  [157, 64.87],
#  [156, 59.2],
#  [157, 53.59],
#  [169, 97.9],
#  [157, 69.72],
#  [157, 79.65],
#  [157, 59.74],
#  [156, 106.71],
#  [159, 93.04],
#  [170, 120.62],
#  [170, 85.67],
#  [158, 89.85],
#  [158, 68.64],
#  [156, 115.51],
#  [174, 119.07],
#  [159, 76.45],
#  [158, 61.95],
#  [159, 142.91],
#  [158, 95.63],
#  [171, 142.05],
#  [181, 119.49],
#  [159, 120.31],
#  [156, 71.27],
#  [158, 80.92],
#  [158, 61.46],
#  [157, 83.54],
#  [158, 70.5],
#  [159, 99.02],
#  [159, 55.39],
#  [157, 87.8],
#  [156, 53.61],
#  [183, 136.2],
#  [181, 108.39],
#  [185, 138.09],
#  [156, 62.05],
#  [175, 117.02],
#  [166, 79.4],
#  [159, 114.93],
#  [157, 63.65],
#  [183, 154.57],
#  [158, 73.73],
#  [156, 96.2],
#  [157, 67.45],
#  [167, 86.71],
#  [160, 67.89],
#  [157, 94.53],
#  [157, 58.44],
#  [159, 81.79],
#  [156, 67.49],
#  [159, 153.0],
#  [181, 126.89],
#  [158, 153.69],
#  [157, 114.84],
#  [159, 110.86],
#  [187, 82.14],
#  [158, 75.34],
#  [157, 60.86],
#  [158, 83.91],
#  [156, 63.98],
#  [157, 93.69],
#  [159, 73.03],
#  [158, 96.72],
#  [158, 87.36],
#  [158, 96.15],
#  [158, 62.49],
#  [156, 103.58],
#  [157, 80.38],
#  [156, 95.71],
#  [162, 80.08],
#  [156, 81.8],
#  [157, 64.8],
#  [176, 104.44],
#  [167, 71.74],
#  [159, 122.73],
#  [156, 88.2],
#  [162, 99.55],
#  [185, 100.23],
#  [158, 119.55],
#  [158, 79.7],
#  [156, 82.05],
#  [157, 58.35],
#  [157, 81.34],
#  [157, 70.73],
#  [156, 93.1],
#  [157, 68.94],
#  [157, 81.89],
#  [156, 62.88],
#  [158, 56.49],
#  [159, 50.48],
#  [180, 106.4],
#  [182, 78.56],
#  [168, 109.48],
#  [158, 88.26],
#  [157, 75.66],
#  [162, 126.34],
#  [168, 114.79],
#  [159, 78.74],
#  [158, 88.02],
#  [174, 73.9],
#  [156, 106.04],
#  [179, 93.08],
#  [158, 123.85],
#  [159, 81.38],
#  [180, 143.8],
#  [179, 108.59],
#  [156, 82.93],
#  [158, 57.43],
#  [156, 91.82],
#  [158, 67.56],
#  [157, 79.67],
#  [156, 55.22],
#  [176, 116.63],
#  [167, 66.71],
#  [156, 96.2],
#  [158, 79.7],
#  [159, 93.72],
#  [159, 84.18],
#  [158, 111.6],
#  [159, 82.82],
#  [156, 96.09],
#  [156, 73.56],
#  [157, 76.78],
#  [158, 62.85],
#  [158, 89.92],
#  [156, 67.08],
#  [157, 72.5],
#  [165, 70.31],
#  [157, 129.21],
#  [156, 111.4],
#  [159, 108.88],
#  [156, 97.95],
#  [158, 108.78],
#  [158, 68.49],
#  [158, 102.83],
#  [157, 67.69],
#  [159, 78.66],
#  [158, 58.15],
#  [176, 67.11],
#  [178, 59.09],
#  [160, 86.2],
#  [157, 61.76],
#  [189, 103.91],
#  [164, 58.38],
#  [159, 119.99],
#  [161, 105.81],
#  [159, 85.71],
#  [159, 58.28],
#  [170, 71.35],
#  [170, 58.14],
#  [159, 101.85],
#  [159, 69.18],
#  [159, 92.91],
#  [185, 109.79],
#  [156, 103.51],
#  [156, 66.18],
#  [156, 83.8],
#  [159, 65.29],
#  [159, 102.85],
#  [158, 74.48],
#  [156, 67.39],
#  [157, 59.41],
#  [157, 100.28],
#  [156, 52.8],
#  [165, 80.4],
#  [159, 54.13],
#  [156, 65.16],
#  [157, 57.0],
#  [158, 103.74],
#  [156, 80.26],
#  [159, 107.43],
#  [157, 72.39],
#  [174, 137.98],
#  [156, 62.48],
#  [156, 89.11],
#  [158, 64.32],
#  [157, 89.51],
#  [158, 66.48],
#  [157, 67.69],
#  [163, 63.84],
#  [167, 105.82],
#  [166, 68.61],
#  [156, 80.0],
#  [171, 85.08],
#  [156, 61.81],
#  [157, 54.59],
#  [159, 74.88],
#  [158, 66.04],
#  [166, 123.97],
#  [162, 94.07],
#  [157, 63.88],
#  [158, 64.51],
#  [157, 67.63],
#  [156, 58.91],
#  [171, 98.45],
#  [178, 94.28],
#  [163, 106.73],
#  [168, 99.21],
#  [159, 138.46],
#  [158, 75.96],
#  [162, 93.38],
#  [158, 73.42],
#  [158, 95.47],
#  [156, 65.67],
#  [161, 58.77],
#  [177, 65.7],
#  [158, 111.6],
#  [159, 80.38],
#  [157, 76.41],
#  [159, 68.37],
#  [167, 110.85],
#  [159, 84.61],
#  [156, 65.93],
#  [156, 50.69],
#  [156, 86.68],
#  [156, 64.21],
#  [181, 111.94],
#  [156, 63.57],
#  [158, 126.95],
#  [159, 87.42],
#  [159, 69.42],
#  [167, 59.83],
#  [158, 89.74],
#  [159, 71.4],
#  [158, 73.33],
#  [158, 64.46],
#  [159, 107.53],
#  [159, 81.09],
#  [157, 82.56],
#  [158, 71.77],
#  [159, 113.02],
#  [159, 79.56],
#  [156, 96.2],
#  [157, 69.33],
#  [156, 87.29],
#  [156, 68.08],
#  [157, 75.09],
#  [156, 59.48],
#  [156, 90.22],
#  [159, 80.27],
#  [178, 131.8],
#  [156, 56.69],
#  [159, 86.48],
#  [158, 76.67],
#  [168, 89.95],
#  [183, 85.8],
#  [156, 121.75],
#  [159, 57.12],
#  [164, 76.89],
#  [158, 55.7],
#  [175, 106.95],
#  [158, 59.82],
#  [156, 82.5],
#  [158, 64.32],
#  [159, 96.09],
#  [158, 68.32],
#  [157, 97.25],
#  [157, 86.64],
#  [173, 127.49],
#  [184, 131.49],
#  [158, 63.66],
#  [157, 52.91],
#  [185, 139.98],
#  [158, 78.15],
#  [174, 121.91],
#  [156, 80.18],
#  [159, 89.82],
#  [159, 60.75],
#  [156, 68.43],
#  [156, 54.65],
#  [156, 83.15],
#  [157, 60.16],
#  [159, 129.86],
#  [159, 102.54],
#  [157, 107.31],
#  [156, 84.61],
#  [165, 84.57],
#  [160, 72.5],
#  [174, 98.54],
#  [156, 56.1],
#  [158, 81.6],
#  [157, 65.58],
#  [166, 107.6],
#  [173, 73.04],
#  [156, 98.42],
#  [159, 74.04],
#  [158, 78.71],
#  [177, 126.05],
#  [156, 85.52],
#  [159, 75.78],
#  [159, 117.9],
#  [158, 68.93],
#  [162, 79.63],
#  [157, 61.78],
#  [182, 133.64],
#  [158, 60.84],
#  [159, 76.3],
#  [159, 59.16],
#  [176, 87.86],
#  [156, 54.58],
#  [158, 83.97],
#  [158, 57.05],
#  [176, 77.64],
#  [159, 55.03],
#  [157, 76.55],
#  [157, 66.52],
#  [157, 90.99],
#  [156, 68.27],
#  [167, 116.18],
#  [158, 87.18],
#  [186, 77.19],
#  [159, 73.37],
#  [159, 90.31],
#  [158, 66.98],
#  [158, 68.98],
#  [159, 55.54],
#  [166, 93.71],
#  [178, 86.8],
#  [158, 148.82],
#  [158, 96.72],
#  [156, 70.95],
#  [157, 61.84],
#  [156, 108.79],
#  [157, 75.18],
#  [161, 64.84],
#  [166, 57.81],
#  [157, 80.78],
#  [156, 72.97],
#  [156, 101.08],
#  [157, 89.26],
#  [176, 99.37],
#  [173, 73.26],
#  [173, 108.67],
#  [165, 84.39],
#  [156, 88.36],
#  [158, 61.02],
#  [156, 97.91],
#  [158, 84.0],
#  [158, 83.08],
#  [157, 65.62],
#  [156, 68.78],
#  [158, 63.39],
#  [157, 81.89],
#  [156, 57.49],
#  [172, 119.03],
#  [161, 71.11],
#  [158, 155.8],
#  [157, 93.71],
#  [157, 91.95],
#  [157, 65.42],
#  [159, 111.95],
#  [157, 87.32],
#  [157, 79.98],
#  [158, 61.06],
#  [159, 101.56],
#  [156, 83.8],
#  [158, 86.62],
#  [159, 67.32],
#  [156, 78.06],
#  [156, 64.48],
#  [159, 103.27],
#  [160, 87.0],
#  ...]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_bmi_train, y_bmi_test = train_test_split(X_train, y_bmi, test_size=0.2, random_state=1)

# %%
from sklearn.kernel_ridge import KernelRidge
from sklearn import  linear_model
from sklearn.svm import SVR
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from math import sqrt

# %%
def report_goodness(model,X_test,y_test,predictor_log=True):
    # Make predictions using the testing set
    y_pred = model.predict(X_test)
    y_true = y_test
    if predictor_log:
        y_true = np.log(y_test)
    print('Model Performance')
    print("Root Mean squared error: %.4f" %sqrt(mean_squared_error(y_true, y_pred)))
    print("Mean squared error: %.4f" %mean_squared_error(y_true, y_pred))
    print('Mean Absolute Error: %.4f' %mean_absolute_error(y_true, y_pred))
    print('Variant score: %.4f' %r2_score(y_true, y_pred))

# %%
model_linear = linear_model.LinearRegression()
model_linear = model_linear.fit(X_train,np.log(y_bmi_train))

report_goodness(model_linear,X_test,y_bmi_test)
# Out:
# Model Performance
# Root Mean squared error: 0.0419
# Mean squared error: 0.0018
# Mean Absolute Error: 0.0325
# Variant score: 0.9667

# %%
model_ridge = Ridge(fit_intercept=True, alpha=0.0015, random_state=4, normalize=True)
model_ridge = model_ridge.fit(X_train,np.log(y_bmi_train))

report_goodness(model_ridge,X_test,y_bmi_test)
# Out:
# Model Performance
# Root Mean squared error: 0.0420
# Mean squared error: 0.0018
# Mean Absolute Error: 0.0326
# Variant score: 0.9666

# %%
model_lasso = Lasso(fit_intercept=True, alpha=0.0015, random_state=4, normalize=True)
model_lasso = model_lasso.fit(X_train,np.log(y_bmi_train))

report_goodness(model_lasso,X_test,y_bmi_test)
# Out:
# Model Performance
# Root Mean squared error: 0.1302
# Mean squared error: 0.0170
# Mean Absolute Error: 0.1075
# Variant score: 0.6786

# %%
weight_model = 'bmi_predictor_bmi_best.model'
joblib.dump(model_ridge, weight_model)
# Out:
# ['bmi_predictor_bmi_best.model']

# %%
label_file = "./updatedsample.csv"

# %%
data_df_test = pd.read_csv(label_file)
data_df_test.drop(['Unnamed: 0'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-c9d45824fd84> in <module>
# ----> 1 data_df_test = pd.read_csv(label_file)
#       2 data_df_test.drop(['Unnamed: 0'], axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./updatedsample.csv' does not exist: b'./updatedsample.csv'

# %%
y_height = data_df_test.height.values ## all labels
y_weight = data_df_test.weight.values ## all labels

# %%
df_bmi = pd.DataFrame(columns=['Ground Truth', 'Estimation'])

# %%
df_bmi['Ground Truth'] = data_df_test['bmi']
df_bmi['Ground Truth']

# %%
temp = []
res = []
temp_test = []
data_test = []

# %%
def test(model,X_test,predictor_log=True):
    # Make predictions using the testing set
    y_pred = model.predict(X_test)
    return y_pred

# %%
for i in  range(len(y_height)):
    data_test.append([y_height[i],y_weight[i]])

# %%
temp = test(model_ridge,data_test)
temp

# %%
for i in temp:
    res.append(math.exp(i))

# %%
res

# %%
len(res)

# %%
df_bmi['Estimation'] = res
df_bmi['Estimation']

# %%
df_bmi.to_csv('bmi_final.csv', index=False)
