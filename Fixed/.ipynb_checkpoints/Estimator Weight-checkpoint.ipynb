# %%
import pandas as pd
import os

import numpy as np
import math
import itertools
import random
from sklearn.externals import joblib

import matplotlib.pyplot as plt
import math
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
label_file = "./weight.csv"

# %%
data_df = pd.read_csv(label_file)
data_df.drop(['Unnamed: 0'], axis=1)
# Out:
#             bmi  gender          name  length  height  weight
# 0     34.207396    Male     img_0.bmp      85     157      57
# 1     26.453720    Male     img_1.bmp      83     156      56
# 2     34.967561  Female     img_2.bmp      99     158      58
# 3     22.044766  Female     img_3.bmp      72     157      57
# 4     37.758789  Female     img_4.bmp     106     157      57
# ...         ...     ...           ...     ...     ...     ...
# 4038  40.422500  Female  img_4038.bmp     121     164      64
# 4039  29.682222  Female  img_4039.bmp     120     163      63
# 4040  61.649679  Female  img_4040.bmp      94     158      58
# 4041  53.741736  Female  img_4041.bmp      94     156      56
# 4042  44.020156  Female  img_4042.bmp      84     157      57
#
# [4043 rows x 6 columns]

# %%
y_height = data_df.height.values ## all labels
y_weight = data_df.weight.values
y_BMI = data_df.bmi.values

# %%
X_train = []

# %%
for i in  y_height:
    X_train.append([0,i])

# %%
X_train
# Out:
# [[0, 157],
#  [0, 156],
#  [0, 158],
#  [0, 157],
#  [0, 157],
#  [0, 180],
#  [0, 156],
#  [0, 156],
#  [0, 180],
#  [0, 176],
#  [0, 156],
#  [0, 159],
#  [0, 158],
#  [0, 171],
#  [0, 158],
#  [0, 157],
#  [0, 173],
#  [0, 159],
#  [0, 161],
#  [0, 157],
#  [0, 159],
#  [0, 156],
#  [0, 156],
#  [0, 156],
#  [0, 159],
#  [0, 157],
#  [0, 183],
#  [0, 158],
#  [0, 156],
#  [0, 156],
#  [0, 163],
#  [0, 156],
#  [0, 157],
#  [0, 156],
#  [0, 166],
#  [0, 181],
#  [0, 158],
#  [0, 185],
#  [0, 156],
#  [0, 157],
#  [0, 157],
#  [0, 174],
#  [0, 169],
#  [0, 170],
#  [0, 159],
#  [0, 159],
#  [0, 163],
#  [0, 157],
#  [0, 166],
#  [0, 157],
#  [0, 157],
#  [0, 158],
#  [0, 159],
#  [0, 159],
#  [0, 158],
#  [0, 157],
#  [0, 180],
#  [0, 159],
#  [0, 159],
#  [0, 158],
#  [0, 156],
#  [0, 156],
#  [0, 158],
#  [0, 156],
#  [0, 163],
#  [0, 157],
#  [0, 163],
#  [0, 159],
#  [0, 168],
#  [0, 159],
#  [0, 157],
#  [0, 169],
#  [0, 178],
#  [0, 183],
#  [0, 174],
#  [0, 177],
#  [0, 157],
#  [0, 179],
#  [0, 158],
#  [0, 182],
#  [0, 158],
#  [0, 159],
#  [0, 159],
#  [0, 159],
#  [0, 158],
#  [0, 158],
#  [0, 160],
#  [0, 178],
#  [0, 159],
#  [0, 158],
#  [0, 159],
#  [0, 158],
#  [0, 173],
#  [0, 174],
#  [0, 180],
#  [0, 185],
#  [0, 180],
#  [0, 157],
#  [0, 166],
#  [0, 158],
#  [0, 165],
#  [0, 171],
#  [0, 157],
#  [0, 159],
#  [0, 159],
#  [0, 156],
#  [0, 160],
#  [0, 157],
#  [0, 178],
#  [0, 171],
#  [0, 156],
#  [0, 157],
#  [0, 169],
#  [0, 166],
#  [0, 188],
#  [0, 156],
#  [0, 159],
#  [0, 158],
#  [0, 156],
#  [0, 158],
#  [0, 178],
#  [0, 157],
#  [0, 159],
#  [0, 159],
#  [0, 156],
#  [0, 159],
#  [0, 167],
#  [0, 163],
#  [0, 158],
#  [0, 157],
#  [0, 158],
#  [0, 159],
#  [0, 157],
#  [0, 159],
#  [0, 157],
#  [0, 159],
#  [0, 159],
#  [0, 156],
#  [0, 167],
#  [0, 157],
#  [0, 156],
#  [0, 158],
#  [0, 168],
#  [0, 159],
#  [0, 158],
#  [0, 156],
#  [0,

#  [0, 158],
#  [0, 157],
#  [0, 156],
#  [0, 158],
#  [0, 157],
#  [0, 156],
#  [0, 172],
#  [0, 161],
#  [0, 158],
#  [0, 157],
#  [0, 157],
#  [0, 157],
#  [0, 159],
#  [0, 157],
#  [0, 157],
#  [0, 158],
#  [0, 159],
#  [0, 156],
#  [0, 158],
#  [0, 159],
#  [0, 156],
#  [0, 156],
#  [0, 159],
#  [0, 160],
#  ...]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_weight_train, y_weight_test = train_test_split(X_train, y_weight, test_size=0.2, random_state=1)

# %%
from sklearn.kernel_ridge import KernelRidge
from sklearn import  linear_model
from sklearn.svm import SVR
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from math import sqrt

# %%
def report_goodness(model,X_test,y_test,predictor_log=True):
    # Make predictions using the testing set
    y_pred = model.predict(X_test)
    y_true = y_test
    if predictor_log:
        y_true = np.log(y_test)
    print('Model Performance')
    print("Root Mean squared error: %.4f" %sqrt(mean_squared_error(y_true, y_pred)))
    print("Mean squared error: %.4f" %mean_squared_error(y_true, y_pred))
    print('Mean Absolute Error: %.4f' %mean_absolute_error(y_true, y_pred))
    print('Variant score: %.4f' %r2_score(y_true, y_pred))

# %%
model_linear = linear_model.LinearRegression()
model_linear = model_linear.fit(X_train,np.log(y_weight_train))

report_goodness(model_linear,X_test,y_weight_test)
# Out:
# Model Performance
# Root Mean squared error: 0.0060
# Mean squared error: 0.0000
# Mean Absolute Error: 0.0045
# Variant score: 0.9977

# %%
model_ridge = Ridge(fit_intercept=True, alpha=0.0015, random_state=4, normalize=True)
model_ridge = model_ridge.fit(X_train,np.log(y_weight_train))

report_goodness(model_ridge,X_test,y_weight_test)
# Out:
# Model Performance
# Root Mean squared error: 0.0060
# Mean squared error: 0.0000
# Mean Absolute Error: 0.0045
# Variant score: 0.9977

# %%
model_lasso = Lasso(fit_intercept=True, alpha=0.0015, random_state=4, normalize=True)
model_lasso = model_lasso.fit(X_train,np.log(y_weight_train))

report_goodness(model_lasso,X_test,y_weight_test)
# Out:
# Model Performance
# Root Mean squared error: 0.0851
# Mean squared error: 0.0072
# Mean Absolute Error: 0.0702
# Variant score: 0.5274

# %%
weight_model = 'weight_predictor_weight_best.model'
joblib.dump(model_ridge, weight_model)
# Out:
# ['weight_predictor_weight_best.model']

# %%
label_file = "./MainSample_test.csv"

# %%
data_df_test = pd.read_csv(label_file)
data_df_test.drop(['Unnamed: 0'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-c9d45824fd84> in <module>
# ----> 1 data_df_test = pd.read_csv(label_file)
#       2 data_df_test.drop(['Unnamed: 0'], axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./MainSample_test.csv' does not exist: b'./MainSample_test.csv'

# %%
y_height = data_df_test.height.values ## all labels

# %%
df_weight = pd.DataFrame(columns=['Ground Truth', 'Estimation'])

# %%
df_weight['Ground Truth'] = data_df_test['weight']
df_weight['Ground Truth']

# %%
temp = []
res = []
temp_test = []
data_test = []

# %%
def test(model,X_test,predictor_log=True):
    # Make predictions using the testing set
    y_pred = model.predict(X_test)
    return y_pred

# %%
for i in  y_height:
    data_test.append([0,i])

# %%
temp = test(model_ridge,data_test)
temp

# %%
for i in temp:
    res.append(math.exp(i))

# %%
res

# %%
len(res)

# %%
df_weight['Estimation'] = res
df_weight['Estimation']

# %%
df_weight.to_csv('weight_final.csv', index=False)
