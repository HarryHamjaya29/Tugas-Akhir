# %%
import pandas as pd
import os

import numpy as np
import math
import random
import itertools
import random
from sklearn.externals import joblib

import matplotlib.pyplot as plt
import math
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
label_file = "Dataset/selection_bmi_9.csv"
data_df = pd.read_csv(label_file)
data_df
# Out:
#           10-19        8-26       11-19       10-20        9-19       10-18  \
# 0    127.141653  121.202310  126.245792  126.317061  124.482931  123.146255
# 1    142.358702  143.171226  143.055933  140.431478  136.894120  137.411790
# 2     89.470666   85.866175   88.481637   86.925255   88.022724   87.664132
# 3    115.693561  115.412304  110.941426  113.225439  112.641023  111.364267
# 4    151.158857  144.474911  149.412182  149.325149  148.081059  150.296374
# ..          ...         ...         ...         ...         ...         ...
# 967   88.294960   88.526832   85.440037   85.708809   85.586214   86.330759
# 968  184.707877  180.013888  180.853532  178.011236  179.513231  185.827877
# 969  230.902577  243.877018  231.397926  226.490618  225.858363  223.785612
# 970  298.187860  276.537520  306.726262  295.705935  284.154887  291.605898
# 971  259.988461  253.339693  250.449596  251.543237  257.841036  262.268946
#
#           11-18        7-26        8-25        bmi
# 0    123.434193  125.363472  123.490890  55.950000
# 1    139.387948  144.059016  139.842769  56.700000
# 2     87.458562   85.702975   84.864598  54.150000
# 3    107.615055  114.039467  113.318136  55.450000
# 4    150.046659  147.634684  144.180443  57.250000
# ..          ...         ...         ...        ...
# 967   84.528102   89.375612   86.400231  22.806990
# 968  183.447540  173.971262  172.525360  23.301714
# 969  226.603177  242.406683  233.976495  23.528365
# 970  300.647634  249.190690  273.791892  23.819676
# 971  255.190125  249.425340  244.773365  23.673004
#
# [972 rows x 10 columns]

# %%
data = data_df.drop(['bmi'], axis=1)

# %%
data_arr = data.to_numpy()

# %%
label = data_df['bmi']
label
# Out:
# 0      55.950000
# 1      56.700000
# 2      54.150000
# 3      55.450000
# 4      57.250000
#          ...
# 967    22.806990
# 968    23.301714
# 969    23.528365
# 970    23.819676
# 971    23.673004
# Name: bmi, Length: 972, dtype: float64

# %%
temp_label = label.to_numpy()
temp_label
# Out:
# array([55.95      , 56.7       , 54.15      , 55.45      , 57.25      ,
#        62.25      , 59.8       , 60.4       , 55.4       , 58.65      ,
#        58.9       , 60.85      , 56.9       , 62.3       , 56.1       ,
#        61.3       , 58.3       , 57.1       , 55.1       , 57.75      ,
#        59.5       , 63.25      , 63.2       , 54.85      , 55.        ,
#        58.1       , 59.05      , 58.        , 57.15      , 57.        ,
#        57.05      , 62.65      , 57.25      , 56.85      , 56.3       ,
#        58.05      , 54.05      , 56.5       , 58.75      , 57.05      ,
#        55.35      , 61.45      , 59.35      , 62.9       , 54.55      ,
#        54.9       , 54.35      , 54.05      , 60.9       , 55.4       ,
#        61.45      , 54.25      , 54.7       , 55.        , 58.25      ,
#        60.45      , 57.3       , 66.9       , 54.2       , 68.95      ,
#        56.1       , 55.85      , 54.45      , 62.6       , 56.05      ,
#        55.25      , 61.35      , 62.65      , 54.9       , 59.85      ,
#        59.25      , 58.1       , 59.9       , 63.        , 56.95      ,
#        54.4       , 60.2       , 54.25      , 55.1       , 54.15      ,
#        60.45      , 56.85      , 60.1       , 61.75      , 59.9       ,
#        54.7       , 64.25      , 58.7       , 56.45      , 54.8       ,
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from math import sqrt
from sklearn.preprocessing import PolynomialFeatures

# %%
def create_polynomial_regression_model(degree):
    #"Creates a polynomial regression model for the given degree"
    poly_features = PolynomialFeatures(degree=degree)
    # transforms the existing features to higher degree features.
    X_train_poly = poly_features.fit_transform(X_train)
    # fit the transformed features to Linear Regression
    poly_model = linear_model.LinearRegression()
    poly_model.fit(X_train_poly, y_train)
    # predicting on training data-set
    y_train_predicted = poly_model.predict(X_train_poly)
#     y_train_predicted = np.expm1(y_train_predicted)
    # predicting on test data-set
    y_test_predict = poly_model.predict(poly_features.fit_transform(X_test))
#     y_test_predict = np.expm1(y_test_predict)
    # evaluating the model on training dataset
    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predicted))
    rmae_train = (mean_absolute_error(y_train, y_train_predicted))
    r2_train = r2_score(y_train, y_train_predicted)
    # evaluating the model on test dataset
    rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predict))
    rmae_test = (mean_absolute_error(y_test, y_test_predict))
    r2_test = r2_score(y_test, y_test_predict)
#     print("The model performance for the training set")
#     print("-------------------------------------------")
#     print("RMSE of training set is {}".format(rmse_train))
#     print("RMAE of training set is {}".format(rmae_train))
#     print("Model score of training set is {}".format(r2_train))
#     print("\n")
    print("The model performance for the test set")
    print("-------------------------------------------")
    print("RMSE of test set is {}".format(rmse_test))
    print("RMAE of test set is {}".format(rmae_test))
    print("Model score of test set is {}".format(r2_test))

# %%
def report_goodness(model,X_test,y_test,predictor_log=True):
    # Make predictions using the testing set
    y_pred = model.predict(X_test)
    y_true = y_test
    if predictor_log:
        y_true = np.log(y_test)
    print('Model Performance')
    print("Root Mean squared error: %.4f" %sqrt(mean_squared_error(y_true, y_pred)))
    print("Mean squared error: %.4f" %mean_squared_error(y_true, y_pred))
    print('Mean Absolute Error: %.4f' %mean_absolute_error(y_true, y_pred))
    print('Variant score: %.4f' %r2_score(y_true, y_pred))

# %%
model_linear = linear_model.LinearRegression()
model_linear = model_linear.fit(X_train,y_train)

report_goodness(model_linear,X_test,y_test, False)
# Out:
# Model Performance
# Root Mean squared error: 18.4882
# Mean squared error: 341.8133
# Mean Absolute Error: 18.3434
# Variant score: -0.0349

# %%
model_ridge = Ridge(fit_intercept=True, alpha=0.0001, random_state=4)
model_ridge = model_ridge.fit(X_train,y_train)

report_goodness(model_ridge,X_test,y_test, False)
# Out:
# Model Performance
# Root Mean squared error: 18.4882
# Mean squared error: 341.8133
# Mean Absolute Error: 18.3434
# Variant score: -0.0349

# %%
model_lasso = Lasso(fit_intercept=True, alpha=0.0001, random_state=4, max_iter=2000)
model_lasso = model_lasso.fit(X_train,y_train)

report_goodness(model_lasso,X_test,y_test,False)
# Out:
# Model Performance
# Root Mean squared error: 18.4058
# Mean squared error: 338.7718
# Mean Absolute Error: 18.2802
# Variant score: -0.0257
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 126684.51372126279, tolerance: 25.944647764279647
#   positive)

# %%
create_polynomial_regression_model(1)
# Out:
# The model performance for the test set
# -------------------------------------------
# RMSE of test set is 18.48819291553156
# RMAE of test set is 18.343426201620446
# Model score of test set is -0.03494298103768201

# %%
create_polynomial_regression_model(2)
# Out:
# The model performance for the test set
# -------------------------------------------
# RMSE of test set is 27.214576576200763
# RMAE of test set is 22.11190810494237
# Model score of test set is -1.2424907406162498

# %%
create_polynomial_regression_model(3)
# Out:
# The model performance for the test set
# -------------------------------------------
# RMSE of test set is 43.347743686487476
# RMAE of test set is 32.708525854290684
# Model score of test set is -4.689321663878316

# %%
create_polynomial_regression_model(4)
# Out:
# The model performance for the test set
# -------------------------------------------
# RMSE of test set is 52582.958073052134
# RMAE of test set is 15478.999535239842
# Model score of test set is -8371773.521694945

# %%
create_polynomial_regression_model(5)
# Out:
# The model performance for the test set
# -------------------------------------------
# RMSE of test set is 1901.0548635351809
# RMAE of test set is 353.6797535426008
# Model score of test set is -10941.506074171772
